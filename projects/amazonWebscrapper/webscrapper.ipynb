# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.chrome.options import Options
import os
import requests

# %%
def scrape_page(data,index): 
    asin_to_find=data[0]
    keyword=data[1]
    search_term = "+".join(keyword.split(" ")).lower()
    for pincode in pincodes:
        found_asin = False
        page = 1
        while(not found_asin):
            driver.get("https://www.amazon.in/s?k=" + search_term + "&page=" + str(page))
            try:
                if page == 1:
                    location_ele = driver.find_element(By.XPATH, '//*[@id="nav-global-location-popover-link"]')
                    location_ele.click()
                    time.sleep(1)
                    location_input = driver.find_element(By.XPATH, '//*[@id="GLUXZipUpdateInput"]')
                    location_input.clear()
                    location_input.send_keys(pincode)
                    location_btn = driver.find_element(By.XPATH, '//*[@id="GLUXZipUpdate"]')
                    location_btn.click()
                    time.sleep(2)
                try:
                    divs = driver.find_elements(By.CSS_SELECTOR, f'div[data-asin="{asin_to_find}"]')
                    if len(divs) == 0:
                        page+=1
                        if(page > max_pages):
                            print(f"item {index} not found in {max_pages} pages on pin {pincode}")
                            output[len(output)] = {
                                "pincode":pincode,
                                "keyword":keyword,
                                "asin":asin_to_find,
                                "rank":">96"
                            }
                            # i+=1
                            break
                    for div in divs:
                        try:
                            anchor = div.find_elements(By.TAG_NAME, "a")
                            href = anchor[0].get_attribute("href")
                            if "ref=sr_1_" in href:
                                try:
                                    rank = int(href.split("ref=sr_1_")[1].split("?")[0])
                                    if page == 1:
                                        if rank<=4 or (rank >= 21 and rank <= 24):
                                            break
                                            # print("div was sponso")
                                        
                                        if rank <= 20:
                                            rank -= 4
                                            # print("rank adjusted")
                                        elif rank > 24 and rank <= 56:
                                            rank -= 8
                                            # print("rank adjusted")
                    
                                    if page == 2:
                                        if (rank >= 49 and rank <= 52) or (rank >= 69 and rank <= 72):
                                            break
                                        
                                        if rank <= 68:
                                            rank -= 4
                                            # print("rank adjusted")
                                        elif rank > 72 and rank <= 104:
                                            rank -= 8
                                            # print("rank adjusted")

                                    
                                except:
                                    rank = href.split("ref=sr_1_")[1].split("?")[0]
                                
                                output[len(output)] = {
                                    "pincode":pincode,
                                    "keyword":keyword,
                                    "asin":asin_to_find,
                                    "rank":rank
                                }
                                # i+=1
                                found_asin = True
                                print(f"item {index} found on pin {pincode}")
                        except:
                            print("anchor error")
                            page += 1
                            if(page > max_pages):
                                print(f"item {index} not found in {max_pages} pages on pin {pincode}")
                                output[len(output)] = {
                                    "pincode":pincode,
                                    "keyword":keyword,
                                    "asin":asin_to_find,
                                    "rank":">96"
                                }
                                # i+=1
                                break
                except:
                    page += 1
                    if(page > max_pages):
                        print(f"item {index} not found in {max_pages} pages on pin {pincode}")
                        output[len(output)] = {
                            "pincode":pincode,
                            "keyword":keyword,
                            "asin":asin_to_find,
                            "rank":">96"
                        }
                        # i+=1
                        break
                
            except:
                print("cannot find change location btn")
                output[len(output)] =  {
                    "pincode":pincode,
                    "keyword":keyword,
                    "asin":asin_to_find,
                    "rank":"-"
                }
                # i+=1
                time.sleep(1)
                break

# %%
def scrape_full(data_in):
    for pincode in pincodes:
        for index,data in enumerate(data_in):
            asin_to_find=data[0]
            keyword=data[1]
            search_term = "+".join(keyword.split(" ")).lower()
            found_asin = False
            page = 1
            while(not found_asin):
                driver.get("https://www.amazon.in/s?k=" + search_term + "&page=" + str(page))
                time.sleep(1)
                try:
                    if index == 0:
                        location_ele = driver.find_element(By.XPATH, '//*[@id="nav-global-location-popover-link"]')
                        location_ele.click()
                        time.sleep(1)
                        location_input = driver.find_element(By.XPATH, '//*[@id="GLUXZipUpdateInput"]')
                        location_input.clear()
                        location_input.send_keys(pincode)
                        location_btn = driver.find_element(By.XPATH, '//*[@id="GLUXZipUpdate"]')
                        location_btn.click()
                        time.sleep(2)
                    try:
                        divs = driver.find_elements(By.CSS_SELECTOR, f'div[data-asin="{asin_to_find}"]')
                        if len(divs) == 0:
                            page+=1
                            if(page > max_pages):
                                print(f"item {index} not found in {max_pages} pages on pin {pincode}")
                                output[len(output)] = {
                                    "pincode":pincode,
                                    "keyword":keyword,
                                    "asin":asin_to_find,
                                    "rank":">96"
                                }
                                # i+=1
                                break
                        for div in divs:
                            try:
                                anchor = div.find_elements(By.TAG_NAME, "a")
                                href = anchor[0].get_attribute("href")
                                if "ref=sr_1_" in href:
                                    try:
                                        rank = int(href.split("ref=sr_1_")[1].split("?")[0])
                                        if page == 1:
                                            if rank<=4 or (rank >= 21 and rank <= 24):
                                                break
                                                # print("div was sponso")
                                            
                                            if rank <= 20:
                                                rank -= 4
                                                # print("rank adjusted")
                                            elif rank > 24 and rank <= 56:
                                                rank -= 8
                                                # print("rank adjusted")
                        
                                        if page == 2:
                                            if (rank >= 49 and rank <= 52) or (rank >= 69 and rank <= 72):
                                                break
                                            
                                            if rank <= 68:
                                                rank -= 4
                                                # print("rank adjusted")
                                            elif rank > 72 and rank <= 104:
                                                rank -= 8
                                                # print("rank adjusted")
    
                                        
                                    except:
                                        rank = href.split("ref=sr_1_")[1].split("?")[0]
                                    
                                    output[len(output)] = {
                                        "pincode":pincode,
                                        "keyword":keyword,
                                        "asin":asin_to_find,
                                        "rank":rank
                                    }
                                    # i+=1
                                    found_asin = True
                                    print(f"item {index} found on pin {pincode}")
                            except:
                                print("anchor error")
                                page += 1
                                if(page > max_pages):
                                    print(f"item {index} not found in {max_pages} pages on pin {pincode}")
                                    output[len(output)] = {
                                        "pincode":pincode,
                                        "keyword":keyword,
                                        "asin":asin_to_find,
                                        "rank":">96"
                                    }
                                    # i+=1
                                    break
                    except:
                        page += 1
                        if(page > max_pages):
                            print(f"item {index} not found in {max_pages} pages on pin {pincode}")
                            output[len(output)] = {
                                "pincode":pincode,
                                "keyword":keyword,
                                "asin":asin_to_find,
                                "rank":">96"
                            }
                            # i+=1
                            break
                    
                except:
                    print("cannot find change location btn")
                    output[len(output)] =  {
                        "pincode":pincode,
                        "keyword":keyword,
                        "asin":asin_to_find,
                        "rank":"-"
                    }
                    # i+=1
                    time.sleep(1)
                    break

# %%
options = Options()
# options.add_argument('--headless=new')
options.add_argument("--incognito")
path = os.getcwd() + "/chromedriver"
service = Service(executable_path=path)
driver = webdriver.Chrome(service=service , options=options)
pincodes = [
    "110001",
    "700001",
    "400008",
    "560056"
]
max_pages = 2
data_in = eval(requests.get("https://script.google.com/macros/s/AKfycbwouhxWGdmkz38DE36FMAY5EPKfKNjji4mDALB0IEUmw1tXbdoNeKMXTWrOQoPp2MmLsg/exec?sheet=Sheet2").text)
time.sleep(2)
output = {}


start_time = time.time()
scrape_full(data_in)
print("--- %s seconds ---" % (time.time() - start_time))


# for index,data in enumerate(data_in):
#     scrape_page(data,index)

r = requests.post("https://script.google.com/macros/s/AKfycbwouhxWGdmkz38DE36FMAY5EPKfKNjji4mDALB0IEUmw1tXbdoNeKMXTWrOQoPp2MmLsg/exec",json=output)
r.text
# Out:
# item 0 found on pin 110001
# item 1 not found in 2 pages on pin 110001
# item 2 found on pin 110001
# item 3 found on pin 110001
# item 4 found on pin 110001
# item 5 found on pin 110001
# item 6 found on pin 110001
# item 7 found on pin 110001
# item 8 found on pin 110001
# item 9 not found in 2 pages on pin 110001
# item 10 not found in 2 pages on pin 110001
# item 11 found on pin 110001
# item 12 not found in 2 pages on pin 110001
# item 13 found on pin 110001
# item 14 found on pin 110001
# item 15 found on pin 110001
# item 16 not found in 2 pages on pin 110001
# item 17 not found in 2 pages on pin 110001
# item 18 not found in 2 pages on pin 110001
# item 19 not found in 2 pages on pin 110001
# item 20 found on pin 110001
# item 21 found on pin 110001
# item 22 found on pin 110001
# item 23 not found in 2 pages on pin 110001
# item 24 not found in 2 pages on pin 110001
# item 25 found on pin 110001
# item 26 found on pin 110001
# item 27 not found in 2 pages on pin 110001
# ...

# %%
driver.close()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 driver.close()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/webscrapper/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:465, in WebDriver.close(self)
#     457 def close(self) -> None:
#     458     """Closes the current window.
#     459
#     460     :Usage:
#    (...)
#     463             driver.close()
#     464     """
# --> 465     self.execute(Command.CLOSE)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/webscrapper/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
# ...

# %%
r = requests.post("https://script.google.com/macros/s/AKfycbwouhxWGdmkz38DE36FMAY5EPKfKNjji4mDALB0IEUmw1tXbdoNeKMXTWrOQoPp2MmLsg/exec",json=output)

# %%
r.text
# Out:
# 'Done!'

# %%
options = Options()
options.add_argument('--headless=new')
options.add_argument("--incognito")
path = os.getcwd() + "/chromedriver"
service = Service(executable_path=path)
driver = webdriver.Chrome(service=service , options=options)
driver.get("https://www.amazon.in/s?k=" + "water+bottle" + "&page=" + str(1))
asin_to_find = "B0CQ58QDMJ"
divs = driver.find_elements(By.CSS_SELECTOR, f'div[data-asin="{asin_to_find}"]')
anchor = divs[0].find_element(By.TAG_NAME, "a")
href = anchor.get_attribute("href")
href
rank = href.split("sr_1_")[1].split("?")[0]
rank
# Out:
# '27'

# %%
output
# Out:
# {0: {'pincode': '110001',
#   'keyword': 'water bottle',
#   'asin': 'B0CQ58QDMJ',
#   'rank': 24},
#  1: {'pincode': '700001',
#   'keyword': 'water bottle',
#   'asin': 'B0CQ58QDMJ',
#   'rank': 36},
#  2: {'pincode': '400008',
#   'keyword': 'water bottle',
#   'asin': 'B0CQ58QDMJ',
#   'rank': 27},
#  3: {'pincode': '560056',
#   'keyword': 'water bottle',
#   'asin': 'B0CQ58QDMJ',
#   'rank': 26},
#  4: {'pincode': '110001',
#   'keyword': 'water bottle for kids',
#   'asin': 'B0CQ5B17JG',
#   'rank': '>96'},
#  5: {'pincode': '700001',
#   'keyword': 'water bottle for kids',
#   'asin': 'B0CQ5B17JG',
#   'rank': '>96'},
#  6: {'pincode': '400008',
#   'keyword': 'water bottle for kids',
#   'asin': 'B0CQ5B17JG',
#   'rank': '-'}}

# %%
    asin_to_find=data[0]
    keyword=data[1]
    search_term = "+".join(keyword.split(" ")).lower()
    for pincode in pincodes:
        found_asin = False
        page = 1
        while(not found_asin):
            driver.get("https://www.amazon.in/s?k=" + search_term + "&page=" + str(page))
            try:
                if page == 1:
                    location_ele = driver.find_element(By.XPATH, '//*[@id="nav-global-location-popover-link"]')
                    location_ele.click()
                    time.sleep(1)
                    location_input = driver.find_element(By.XPATH, '//*[@id="GLUXZipUpdateInput"]')
                    location_input.clear()
                    location_input.send_keys(pincode)
                    location_btn = driver.find_element(By.XPATH, '//*[@id="GLUXZipUpdate"]')
                    location_btn.click()
                    time.sleep(2)
                try:
                    divs = driver.find_elements(By.CSS_SELECTOR, f'div[data-asin="{asin_to_find}"]')
                    if len(divs) == 0:
                        page+=1
                        if(page > max_pages):
                            print(f"item {index} not found in {max_pages} pages on pin {pincode}")
                            output[i] = {
                                "pincode":pincode,
                                "keyword":keyword,
                                "asin":asin_to_find,
                                "rank":">96"
                            }
                            i+=1
                            break
                    for div in divs:
                        try:
                            anchor = div.find_elements(By.TAG_NAME, "a")
                            href = anchor[0].get_attribute("href")
                            if "ref=sr_1_" in href:
                                try:
                                    rank = int(href.split("ref=sr_1_")[1].split("?")[0])
                                    if page == 1:
                                        if rank<=4 or (rank >= 21 and rank <= 24):
                                            break
                                            print("div was sponso")
                                        
                                        if rank <= 20:
                                            rank -= 4
                                            print("rank adjusted")
                                        elif rank > 24 and rank <= 56:
                                            rank -= 8
                                            print("rank adjusted")
                    
                                    if page == 2:
                                        if (rank >= 49 and rank <= 52) or (rank >= 69 and rank <= 72):
                                            break
                                        
                                        if rank <= 68:
                                            rank -= 4
                                            print("rank adjusted")
                                        elif rank > 72 and rank <= 104:
                                            rank -= 8
                                            print("rank adjusted")

                                    
                                except:
                                    rank = href.split("ref=sr_1_")[1].split("?")[0]
                                
                                output[i] = {
                                    "pincode":pincode,
                                    "keyword":keyword,
                                    "asin":asin_to_find,
                                    "rank":rank
                                }
                                i+=1
                                found_asin = True
                                print(f"item {index} found on pin {pincode}")
                        except:
                            print("anchor error")
                            page += 1
                            if(page > max_pages):
                                print(f"item {index} not found in {max_pages} pages on pin {pincode}")
                                output[i] = {
                                    "pincode":pincode,
                                    "keyword":keyword,
                                    "asin":asin_to_find,
                                    "rank":">96"
                                }
                                i+=1
                                break
                except:
                    page += 1
                    if(page > max_pages):
                        print(f"item {index} not found in {max_pages} pages on pin {pincode}")
                        output[i] = {
                            "pincode":pincode,
                            "keyword":keyword,
                            "asin":asin_to_find,
                            "rank":">96"
                        }
                        i+=1
                        breakB0CQ58QDMJ
                
            except:
                print("cannot find change location btn")
                output[i] =  {
                    "pincode":pincode,
                    "keyword":keyword,
                    "asin":asin_to_find,
                    "rank":"-"
                }
                i+=1
                time.sleep(1)
                break

# %%
from bs4 import BeautifulSoup

# %%
asins = ["B0CQ58QDMJ","B0D74KJ1WD"]
headers = {"User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:127.0) Gecko/20100101 Firefox/127.0"}
url_sheet = "https://script.google.com/macros/s/AKfycbw8A731qtF2FdmTWfGhCC5cEkun_MeUnmhmjklGAP2VQRRiv19GrPF1YuBxHBi0TS6B/exec?sheet=6.%20NEW-+Keyword+Ranking"
data_in = eval(requests.get(url_sheet).text)
asins=[]
for i in range(1,len(data_in)):
    asins.append(data_in[i][2])
send = {}
asins = set(asins)
print(asins)
for asin in asins:
    url = "https://www.amazon.in/dp/" + str(asin)
    html_page = requests.get(url,headers=headers)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    
    try:
        rating_div = soup.find("div",id="averageCustomerReviews")
        rating = rating_div.find("span",class_="a-size-base a-color-base").text
        rating_count = soup.find("span",id="acrCustomerReviewText").text
    except:
        rating = "N/A"
        rating_count = "N/A"
        
    price_div = soup.find("div",id="corePriceDisplay_desktop_feature_div")
    price = price_div.find("span", class_="a-price-whole").text
    
    aplus_prema_div = soup.find("div",id="aplus_feature_div")
    aplus_middle_div = aplus_prema_div.find("div",attrs={"cel_widget_id":"aplus"})
    if aplus_middle_div:
        aplus_stat = aplus_middle_div.find("div")["class"][-1]
    else:
        aplus_stat = None

     send[i] = {
    	"asin":asin,
    	"price":price,
    	"rating":rating,
    	"rating_count":rating_count,
    	"aplus_stat":aplus_stat
    }

print(send)
# Out:
# {'B0D6CTLM5Z', 'B0D6GQCGP7', 'B0CQ5BL1P6', 'B0BVBQ17P1', 'B0CQ58QDMJ', 'B0C6FKNP4L', 'B0D4SJRB4T', 'B0D6K73T79', 'B0CQ5BTDQK', 'B0D6CMPM5Z', 'B0D6WCLSLS', 'B0CQ5B17JG', 'B0D74NQPCC', 'B0CQ58F6JP', 'B0D6CRB3PT', 'B0D6CTDRY8', 'B0D7772R45', 'B0CQ58MKRR', 'B0D5YL3C9Y', 'B0CQ5B3Y44', 'B0D6CJ1Q8D', 'B0D6CQMVG7', 'B0CQ581TW3', 'B0BVB6XQMT', 'B0D6CFD2SN', 'B0CQ55YG32', 'B0CQ57BBDP', 'B0CQ4TMVG9', 'B0CQ59VKJK', 'B0CQ58F2P9'}
# 415  5.0  26 ratings aplus-premium
# 399  5.0  10 ratings aplus-premium
# 2,375  4.2  138 ratings aplus-premium
# 899  4.0  558 ratings aplus-standard
# 419  4.2  138 ratings aplus-premium
# 999  4.0  558 ratings None
# 1,749  4.0  558 ratings aplus-standard
# 419  4.2  138 ratings aplus-premium
# 1,239  4.0  115 ratings aplus-premium
# 810  5.0  10 ratings aplus-premium
# 455  5.0  26 ratings aplus-premium
# 385  4.2  138 ratings aplus-premium
# 455  2.5  2 ratings aplus-premium
# 759  4.2  138 ratings aplus-premium
# 879  5.0  26 ratings aplus-premium
# ...
